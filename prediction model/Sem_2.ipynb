# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv('student_data_semester_2.csv')

# Split the data into features and targets
X = df.drop(columns=['Student_ID', 'Grade', 'Dropout_Risk_%'])
y_grade = df['Grade']
y_dropout = df['Dropout_Risk_%']

# Convert Grade to numeric (O = 10, A = 9, B = 8, C = 7, D = 6, E = 5, F = 0)
grade_mapping = {'O': 10,'E': 9 , 'A': 8, 'B': 7, 'C': 6, 'D': 5,  'F': 0}
y_grade = y_grade.map(grade_mapping)

# Split data into train and test sets (80% train, 20% test)
X_train, X_test, y_train_grade, y_test_grade, y_train_dropout, y_test_dropout = train_test_split(
    X, y_grade, y_dropout, test_size=0.2, random_state=42
)

# Standardize the data (important for deep learning models)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
 import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the neural network model
grade_model = Sequential()

# Input layer
grade_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
grade_model.add(Dense(128, activation='relu'))
grade_model.add(Dropout(0.2))
grade_model.add(Dense(64, activation='relu'))
grade_model.add(Dropout(0.2))

# Output layer
grade_model.add(Dense(1, activation='linear'))  # For regression to predict grade numerically

# Compile the model
grade_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Train the model
grade_model.fit(X_train_scaled, y_train_grade, epochs=150, batch_size=32, validation_data=(X_test_scaled, y_test_grade))

# Evaluate the model
y_pred_grade = grade_model.predict(X_test_scaled)
y_pred_grade = y_pred_grade.round()  # Convert continuous output to nearest grade (0-10)

# Calculate accuracy
accuracy = accuracy_score(y_test_grade, y_pred_grade)

print(f"Deep Learning Grade Prediction Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/150
# 50/50 [==============================] - 2s 13ms/step - loss: 18.4561 - accuracy: 0.0025 - val_loss: 2.8549 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 50/50 [==============================] - 0s 5ms/step - loss: 3.3403 - accuracy: 0.0000e+00 - val_loss: 2.0694 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.6390 - accuracy: 0.0000e+00 - val_loss: 1.8768 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.4623 - accuracy: 0.0000e+00 - val_loss: 1.7594 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.2933 - accuracy: 0.0000e+00 - val_loss: 1.6358 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.0564 - accuracy: 0.0000e+00 - val_loss: 1.4871 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.8040 - accuracy: 0.0000e+00 - val_loss: 1.4526 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 50/50 [==============================] - 0s 4ms/step - loss: 1.8090 - accuracy: 0.0000e+00 - val_loss: 1.3202 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 50/50 [==============================] - 0s 3ms/step - loss: 1.6246 - accuracy: 0.0000e+00 - val_loss: 1.2584 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4092 - accuracy: 0.0000e+00 - val_loss: 1.1762 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 50/50 [==============================] - 0s 2ms/step - loss: 1.5242 - accuracy: 0.0019 - val_loss: 1.1320 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.4242 - accuracy: 0.0025 - val_loss: 1.1144 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.2895 - accuracy: 0.0031 - val_loss: 1.0404 - val_accuracy: 0.0025
# Epoch 14/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.2438 - accuracy: 0.0069 - val_loss: 0.9942 - val_accuracy: 0.0025
# Epoch 15/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.1909 - accuracy: 0.0081 - val_loss: 0.9267 - val_accuracy: 0.0025
# Epoch 16/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.1820 - accuracy: 0.0050 - val_loss: 0.9494 - val_accuracy: 0.0075
# Epoch 17/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.1443 - accuracy: 0.0094 - val_loss: 0.9385 - val_accuracy: 0.0100
# Epoch 18/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.1338 - accuracy: 0.0106 - val_loss: 0.9777 - val_accuracy: 0.0075
# Epoch 19/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.0306 - accuracy: 0.0125 - val_loss: 0.8842 - val_accuracy: 0.0025
# Epoch 20/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9530 - accuracy: 0.0106 - val_loss: 0.8429 - val_accuracy: 0.0075
# Epoch 21/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.0197 - accuracy: 0.0113 - val_loss: 0.8141 - val_accuracy: 0.0075
# Epoch 22/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9507 - accuracy: 0.0119 - val_loss: 0.7695 - val_accuracy: 0.0075
# Epoch 23/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9901 - accuracy: 0.0137 - val_loss: 0.7590 - val_accuracy: 0.0075
# Epoch 24/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9941 - accuracy: 0.0156 - val_loss: 0.7319 - val_accuracy: 0.0125
# Epoch 25/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8785 - accuracy: 0.0169 - val_loss: 0.7207 - val_accuracy: 0.0125
# Epoch 26/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9129 - accuracy: 0.0156 - val_loss: 0.6740 - val_accuracy: 0.0075
# Epoch 27/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8912 - accuracy: 0.0144 - val_loss: 0.7690 - val_accuracy: 0.0150
# Epoch 28/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9208 - accuracy: 0.0200 - val_loss: 0.6749 - val_accuracy: 0.0075
# Epoch 29/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8563 - accuracy: 0.0162 - val_loss: 0.7137 - val_accuracy: 0.0100
# Epoch 30/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8171 - accuracy: 0.0162 - val_loss: 0.7306 - val_accuracy: 0.0200
# Epoch 31/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8518 - accuracy: 0.0175 - val_loss: 0.6704 - val_accuracy: 0.0175
# Epoch 32/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8011 - accuracy: 0.0188 - val_loss: 0.6518 - val_accuracy: 0.0100
# Epoch 33/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8009 - accuracy: 0.0194 - val_loss: 0.6670 - val_accuracy: 0.0150
# Epoch 34/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7996 - accuracy: 0.0206 - val_loss: 0.6703 - val_accuracy: 0.0100
# Epoch 35/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7844 - accuracy: 0.0206 - val_loss: 0.6234 - val_accuracy: 0.0150
# Epoch 36/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7755 - accuracy: 0.0169 - val_loss: 0.6313 - val_accuracy: 0.0200
# Epoch 37/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8049 - accuracy: 0.0213 - val_loss: 0.5667 - val_accuracy: 0.0125
# Epoch 38/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7558 - accuracy: 0.0200 - val_loss: 0.6347 - val_accuracy: 0.0225
# Epoch 39/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7590 - accuracy: 0.0194 - val_loss: 0.5833 - val_accuracy: 0.0200
# Epoch 40/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7731 - accuracy: 0.0219 - val_loss: 0.5590 - val_accuracy: 0.0125
# Epoch 41/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7692 - accuracy: 0.0206 - val_loss: 0.5795 - val_accuracy: 0.0200
# Epoch 42/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7246 - accuracy: 0.0206 - val_loss: 0.5334 - val_accuracy: 0.0200
# Epoch 43/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7812 - accuracy: 0.0213 - val_loss: 0.6348 - val_accuracy: 0.0200
# Epoch 44/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7009 - accuracy: 0.0237 - val_loss: 0.5888 - val_accuracy: 0.0175
# Epoch 45/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7447 - accuracy: 0.0231 - val_loss: 0.5644 - val_accuracy: 0.0150
# Epoch 46/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6792 - accuracy: 0.0213 - val_loss: 0.6027 - val_accuracy: 0.0150
# Epoch 47/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7295 - accuracy: 0.0231 - val_loss: 0.5657 - val_accuracy: 0.0200
# Epoch 48/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6971 - accuracy: 0.0225 - val_loss: 0.5137 - val_accuracy: 0.0100
# Epoch 49/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6474 - accuracy: 0.0219 - val_loss: 0.5657 - val_accuracy: 0.0225
# Epoch 50/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7387 - accuracy: 0.0250 - val_loss: 0.6709 - val_accuracy: 0.0175
# Epoch 51/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6793 - accuracy: 0.0237 - val_loss: 0.5084 - val_accuracy: 0.0200
# Epoch 52/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.0237 - val_loss: 0.5607 - val_accuracy: 0.0225
# Epoch 53/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6485 - accuracy: 0.0237 - val_loss: 0.5202 - val_accuracy: 0.0150
# Epoch 54/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.0262 - val_loss: 0.5244 - val_accuracy: 0.0150
# Epoch 55/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6391 - accuracy: 0.0213 - val_loss: 0.5350 - val_accuracy: 0.0225
# Epoch 56/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6514 - accuracy: 0.0250 - val_loss: 0.5292 - val_accuracy: 0.0175
# Epoch 57/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6011 - accuracy: 0.0250 - val_loss: 0.5293 - val_accuracy: 0.0225
# Epoch 58/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6201 - accuracy: 0.0237 - val_loss: 0.4896 - val_accuracy: 0.0225
# Epoch 59/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 0.0244 - val_loss: 0.4950 - val_accuracy: 0.0225
# Epoch 60/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6255 - accuracy: 0.0250 - val_loss: 0.4428 - val_accuracy: 0.0225
# Epoch 61/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5898 - accuracy: 0.0256 - val_loss: 0.4692 - val_accuracy: 0.0225
# Epoch 62/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6139 - accuracy: 0.0250 - val_loss: 0.4733 - val_accuracy: 0.0225
# Epoch 63/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.0250 - val_loss: 0.4987 - val_accuracy: 0.0225
# Epoch 64/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6135 - accuracy: 0.0244 - val_loss: 0.5022 - val_accuracy: 0.0225
# Epoch 65/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5805 - accuracy: 0.0250 - val_loss: 0.4716 - val_accuracy: 0.0225
# Epoch 66/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5504 - accuracy: 0.0256 - val_loss: 0.4563 - val_accuracy: 0.0200
# Epoch 67/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5504 - accuracy: 0.0256 - val_loss: 0.4486 - val_accuracy: 0.0225
# Epoch 68/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5812 - accuracy: 0.0244 - val_loss: 0.4615 - val_accuracy: 0.0225
# Epoch 69/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5501 - accuracy: 0.0244 - val_loss: 0.4779 - val_accuracy: 0.0225
# Epoch 70/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5725 - accuracy: 0.0237 - val_loss: 0.5892 - val_accuracy: 0.0225
# Epoch 71/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5656 - accuracy: 0.0256 - val_loss: 0.4968 - val_accuracy: 0.0225
# Epoch 72/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5548 - accuracy: 0.0256 - val_loss: 0.4821 - val_accuracy: 0.0225
# Epoch 73/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5412 - accuracy: 0.0250 - val_loss: 0.4386 - val_accuracy: 0.0200
# Epoch 74/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5924 - accuracy: 0.0250 - val_loss: 0.4638 - val_accuracy: 0.0200
# Epoch 75/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5533 - accuracy: 0.0231 - val_loss: 0.4945 - val_accuracy: 0.0225
# Epoch 76/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5245 - accuracy: 0.0244 - val_loss: 0.4751 - val_accuracy: 0.0225
# Epoch 77/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5435 - accuracy: 0.0262 - val_loss: 0.4487 - val_accuracy: 0.0225
# Epoch 78/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 0.0269 - val_loss: 0.4373 - val_accuracy: 0.0225
# Epoch 79/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5563 - accuracy: 0.0231 - val_loss: 0.4804 - val_accuracy: 0.0225
# Epoch 80/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5667 - accuracy: 0.0262 - val_loss: 0.5064 - val_accuracy: 0.0225
# Epoch 81/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5322 - accuracy: 0.0237 - val_loss: 0.4281 - val_accuracy: 0.0150
# Epoch 82/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5569 - accuracy: 0.0256 - val_loss: 0.4526 - val_accuracy: 0.0225
# Epoch 83/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5615 - accuracy: 0.0275 - val_loss: 0.4026 - val_accuracy: 0.0200
# Epoch 84/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5375 - accuracy: 0.0237 - val_loss: 0.4340 - val_accuracy: 0.0225
# Epoch 85/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5423 - accuracy: 0.0244 - val_loss: 0.4887 - val_accuracy: 0.0225
# Epoch 86/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5290 - accuracy: 0.0256 - val_loss: 0.4250 - val_accuracy: 0.0225
# Epoch 87/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4891 - accuracy: 0.0244 - val_loss: 0.4282 - val_accuracy: 0.0200
# Epoch 88/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5204 - accuracy: 0.0262 - val_loss: 0.5006 - val_accuracy: 0.0225
# Epoch 89/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4896 - accuracy: 0.0244 - val_loss: 0.4258 - val_accuracy: 0.0175
# Epoch 90/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4837 - accuracy: 0.0256 - val_loss: 0.4616 - val_accuracy: 0.0225
# Epoch 91/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.0250 - val_loss: 0.4508 - val_accuracy: 0.0225
# Epoch 92/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4727 - accuracy: 0.0262 - val_loss: 0.4389 - val_accuracy: 0.0225
# Epoch 93/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4861 - accuracy: 0.0269 - val_loss: 0.4380 - val_accuracy: 0.0200
# Epoch 94/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4328 - accuracy: 0.0256 - val_loss: 0.4409 - val_accuracy: 0.0225
# Epoch 95/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4904 - accuracy: 0.0244 - val_loss: 0.4568 - val_accuracy: 0.0200
# Epoch 96/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4580 - accuracy: 0.0244 - val_loss: 0.4388 - val_accuracy: 0.0200
# Epoch 97/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4843 - accuracy: 0.0231 - val_loss: 0.4437 - val_accuracy: 0.0200
# Epoch 98/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4678 - accuracy: 0.0250 - val_loss: 0.4480 - val_accuracy: 0.0200
# Epoch 99/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4548 - accuracy: 0.0269 - val_loss: 0.4283 - val_accuracy: 0.0200
# Epoch 100/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4536 - accuracy: 0.0213 - val_loss: 0.4287 - val_accuracy: 0.0225
# Epoch 101/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4838 - accuracy: 0.0250 - val_loss: 0.4683 - val_accuracy: 0.0225
# Epoch 102/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4647 - accuracy: 0.0237 - val_loss: 0.4449 - val_accuracy: 0.0225
# Epoch 103/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4413 - accuracy: 0.0256 - val_loss: 0.4163 - val_accuracy: 0.0200
# Epoch 104/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4538 - accuracy: 0.0231 - val_loss: 0.4299 - val_accuracy: 0.0225
# Epoch 105/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4862 - accuracy: 0.0250 - val_loss: 0.4560 - val_accuracy: 0.0175
# Epoch 106/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4464 - accuracy: 0.0250 - val_loss: 0.4303 - val_accuracy: 0.0225
# Epoch 107/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4539 - accuracy: 0.0237 - val_loss: 0.4500 - val_accuracy: 0.0200
# Epoch 108/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4866 - accuracy: 0.0269 - val_loss: 0.4284 - val_accuracy: 0.0225
# Epoch 109/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4598 - accuracy: 0.0244 - val_loss: 0.4271 - val_accuracy: 0.0200
# Epoch 110/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4572 - accuracy: 0.0256 - val_loss: 0.4973 - val_accuracy: 0.0225
# Epoch 111/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4305 - accuracy: 0.0244 - val_loss: 0.3979 - val_accuracy: 0.0225
# Epoch 112/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4302 - accuracy: 0.0269 - val_loss: 0.4115 - val_accuracy: 0.0200
# Epoch 113/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4212 - accuracy: 0.0231 - val_loss: 0.4316 - val_accuracy: 0.0225
# Epoch 114/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4001 - accuracy: 0.0256 - val_loss: 0.4112 - val_accuracy: 0.0175
# Epoch 115/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4060 - accuracy: 0.0225 - val_loss: 0.4604 - val_accuracy: 0.0200
# Epoch 116/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3897 - accuracy: 0.0269 - val_loss: 0.3914 - val_accuracy: 0.0175
# Epoch 117/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4383 - accuracy: 0.0219 - val_loss: 0.4326 - val_accuracy: 0.0200
# Epoch 118/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3861 - accuracy: 0.0250 - val_loss: 0.4155 - val_accuracy: 0.0200
# Epoch 119/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4113 - accuracy: 0.0269 - val_loss: 0.4458 - val_accuracy: 0.0200
# Epoch 120/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3989 - accuracy: 0.0250 - val_loss: 0.3870 - val_accuracy: 0.0175
# Epoch 121/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4025 - accuracy: 0.0256 - val_loss: 0.3892 - val_accuracy: 0.0175
# Epoch 122/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4000 - accuracy: 0.0256 - val_loss: 0.4205 - val_accuracy: 0.0200
# Epoch 123/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4386 - accuracy: 0.0237 - val_loss: 0.3988 - val_accuracy: 0.0200
# Epoch 124/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4004 - accuracy: 0.0281 - val_loss: 0.3795 - val_accuracy: 0.0125
# Epoch 125/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4261 - accuracy: 0.0237 - val_loss: 0.3744 - val_accuracy: 0.0125
# Epoch 126/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4052 - accuracy: 0.0213 - val_loss: 0.3915 - val_accuracy: 0.0175
# Epoch 127/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3908 - accuracy: 0.0231 - val_loss: 0.4160 - val_accuracy: 0.0200
# Epoch 128/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4010 - accuracy: 0.0237 - val_loss: 0.4300 - val_accuracy: 0.0200
# Epoch 129/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.0262 - val_loss: 0.3542 - val_accuracy: 0.0125
# Epoch 130/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3978 - accuracy: 0.0237 - val_loss: 0.4001 - val_accuracy: 0.0125
# Epoch 131/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4018 - accuracy: 0.0213 - val_loss: 0.4066 - val_accuracy: 0.0175
# Epoch 132/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3961 - accuracy: 0.0244 - val_loss: 0.4468 - val_accuracy: 0.0200
# Epoch 133/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3959 - accuracy: 0.0237 - val_loss: 0.4099 - val_accuracy: 0.0175
# Epoch 134/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3539 - accuracy: 0.0244 - val_loss: 0.3442 - val_accuracy: 0.0175
# Epoch 135/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3657 - accuracy: 0.0237 - val_loss: 0.3609 - val_accuracy: 0.0175
# Epoch 136/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3828 - accuracy: 0.0256 - val_loss: 0.3863 - val_accuracy: 0.0175
# Epoch 137/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3916 - accuracy: 0.0256 - val_loss: 0.3916 - val_accuracy: 0.0175
# Epoch 138/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3802 - accuracy: 0.0256 - val_loss: 0.3994 - val_accuracy: 0.0200
# Epoch 139/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.0250 - val_loss: 0.4071 - val_accuracy: 0.0225
# Epoch 140/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3647 - accuracy: 0.0269 - val_loss: 0.3924 - val_accuracy: 0.0175
# Epoch 141/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3615 - accuracy: 0.0225 - val_loss: 0.3891 - val_accuracy: 0.0175
# Epoch 142/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3546 - accuracy: 0.0250 - val_loss: 0.3799 - val_accuracy: 0.0175
# Epoch 143/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3744 - accuracy: 0.0262 - val_loss: 0.4131 - val_accuracy: 0.0200
# Epoch 144/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3772 - accuracy: 0.0244 - val_loss: 0.4443 - val_accuracy: 0.0200
# Epoch 145/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3428 - accuracy: 0.0244 - val_loss: 0.4692 - val_accuracy: 0.0200
# Epoch 146/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3427 - accuracy: 0.0250 - val_loss: 0.4040 - val_accuracy: 0.0200
# Epoch 147/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3442 - accuracy: 0.0231 - val_loss: 0.3980 - val_accuracy: 0.0175
# Epoch 148/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3766 - accuracy: 0.0250 - val_loss: 0.4251 - val_accuracy: 0.0200
# Epoch 149/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3511 - accuracy: 0.0262 - val_loss: 0.3980 - val_accuracy: 0.0100
# Epoch 150/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3287 - accuracy: 0.0237 - val_loss: 0.4440 - val_accuracy: 0.0175
# 13/13 [==============================] - 0s 2ms/step
# Deep Learning Grade Prediction Accuracy: 72.25%

# %%
# Build the neural network model for dropout risk prediction
dropout_model = Sequential()

# Input layer
dropout_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
dropout_model.add(Dense(128, activation='relu'))
dropout_model.add(Dropout(0.2))
dropout_model.add(Dense(64, activation='relu'))
dropout_model.add(Dropout(0.2))

# Output layer
dropout_model.add(Dense(1, activation='linear'))  # For regression to predict dropout risk

# Compile the model
dropout_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
dropout_model.fit(X_train_scaled, y_train_dropout, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test_dropout))

# Evaluate the model
y_pred_dropout = dropout_model.predict(X_test_scaled)

from sklearn.metrics import mean_squared_error, r2_score

# Calculate RMSE (Root Mean Squared Error)
dropout_rmse = mean_squared_error(y_test_dropout, y_pred_dropout) ** 0.5

# Calculate R-squared score
dropout_r2 = r2_score(y_test_dropout, y_pred_dropout)

print(f"Deep Learning Dropout Risk RMSE: {dropout_rmse:.2f}")
print(f"Deep Learning Dropout Risk R-squared: {dropout_r2:.2f}")
# Out:
# Epoch 1/50
# 50/50 [==============================] - 2s 12ms/step - loss: 679.2281 - mae: 18.1596 - val_loss: 153.9749 - val_mae: 10.5547
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 79.0925 - mae: 6.6445 - val_loss: 38.7816 - val_mae: 4.6572
# Epoch 3/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.9977 - mae: 4.8854 - val_loss: 35.0265 - val_mae: 4.4659
# Epoch 4/50
# 50/50 [==============================] - 0s 5ms/step - loss: 43.1554 - mae: 4.7773 - val_loss: 32.8201 - val_mae: 4.3343
# Epoch 5/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.7995 - mae: 4.8290 - val_loss: 34.9638 - val_mae: 4.4720
# Epoch 6/50
# 50/50 [==============================] - 0s 6ms/step - loss: 43.0346 - mae: 4.7209 - val_loss: 33.5391 - val_mae: 4.4097
# Epoch 7/50
# 50/50 [==============================] - 0s 6ms/step - loss: 42.6967 - mae: 4.6347 - val_loss: 34.7747 - val_mae: 4.4647
# Epoch 8/50
# 50/50 [==============================] - 0s 6ms/step - loss: 41.9057 - mae: 4.5434 - val_loss: 31.9010 - val_mae: 4.2953
# Epoch 9/50
# 50/50 [==============================] - 0s 6ms/step - loss: 40.5122 - mae: 4.4874 - val_loss: 32.0711 - val_mae: 4.3159
# Epoch 10/50
# 50/50 [==============================] - 0s 6ms/step - loss: 39.9407 - mae: 4.4865 - val_loss: 31.7509 - val_mae: 4.3072
# Epoch 11/50
# 50/50 [==============================] - 0s 5ms/step - loss: 38.7655 - mae: 4.3885 - val_loss: 31.0706 - val_mae: 4.2432
# Epoch 12/50
# 50/50 [==============================] - 0s 6ms/step - loss: 35.1918 - mae: 4.2445 - val_loss: 31.2167 - val_mae: 4.2331
# Epoch 13/50
# 50/50 [==============================] - 0s 7ms/step - loss: 37.1889 - mae: 4.2655 - val_loss: 30.8561 - val_mae: 4.2084
# Epoch 14/50
# 50/50 [==============================] - 0s 7ms/step - loss: 35.4923 - mae: 4.1374 - val_loss: 30.8803 - val_mae: 4.2259
# Epoch 15/50
# 50/50 [==============================] - 0s 7ms/step - loss: 34.6458 - mae: 4.1021 - val_loss: 30.9499 - val_mae: 4.2081
# Epoch 16/50
# 50/50 [==============================] - 0s 6ms/step - loss: 32.4202 - mae: 4.0563 - val_loss: 33.2165 - val_mae: 4.2944
# Epoch 17/50
# 50/50 [==============================] - 0s 5ms/step - loss: 33.6203 - mae: 4.0638 - val_loss: 29.6906 - val_mae: 4.1260
# Epoch 18/50
# 50/50 [==============================] - 0s 5ms/step - loss: 34.9514 - mae: 4.1555 - val_loss: 30.7691 - val_mae: 4.2155
# Epoch 19/50
# 50/50 [==============================] - 0s 5ms/step - loss: 32.1581 - mae: 4.0366 - val_loss: 29.8662 - val_mae: 4.1912
# Epoch 20/50
# 50/50 [==============================] - 0s 5ms/step - loss: 34.5206 - mae: 4.0695 - val_loss: 34.9600 - val_mae: 4.3607
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 33.4354 - mae: 3.9966 - val_loss: 29.5072 - val_mae: 4.0996
# Epoch 22/50
# 50/50 [==============================] - 0s 6ms/step - loss: 36.5274 - mae: 4.1106 - val_loss: 29.9932 - val_mae: 4.1357
# Epoch 23/50
# 50/50 [==============================] - 0s 5ms/step - loss: 34.7727 - mae: 3.9517 - val_loss: 29.9622 - val_mae: 4.1546
# Epoch 24/50
# 50/50 [==============================] - 0s 5ms/step - loss: 29.9907 - mae: 3.7927 - val_loss: 29.5761 - val_mae: 4.0950
# Epoch 25/50
# 50/50 [==============================] - 0s 5ms/step - loss: 31.9641 - mae: 3.8413 - val_loss: 30.0484 - val_mae: 4.1035
# Epoch 26/50
# 50/50 [==============================] - 0s 6ms/step - loss: 29.4592 - mae: 3.7443 - val_loss: 31.0319 - val_mae: 4.1270
# Epoch 27/50
# 50/50 [==============================] - 0s 6ms/step - loss: 29.9472 - mae: 3.7946 - val_loss: 31.1174 - val_mae: 4.1842
# Epoch 28/50
# 50/50 [==============================] - 0s 6ms/step - loss: 29.4268 - mae: 3.7778 - val_loss: 31.0766 - val_mae: 4.1645
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 28.5409 - mae: 3.6979 - val_loss: 29.1858 - val_mae: 4.1234
# Epoch 30/50
# 50/50 [==============================] - 0s 5ms/step - loss: 29.4662 - mae: 3.7001 - val_loss: 27.8418 - val_mae: 4.0141
# Epoch 31/50
# 50/50 [==============================] - 0s 7ms/step - loss: 28.5490 - mae: 3.6960 - val_loss: 30.9001 - val_mae: 4.2153
# Epoch 32/50
# 50/50 [==============================] - 0s 6ms/step - loss: 26.9086 - mae: 3.6021 - val_loss: 33.6307 - val_mae: 4.2666
# Epoch 33/50
# 50/50 [==============================] - 0s 5ms/step - loss: 29.9025 - mae: 3.7731 - val_loss: 29.3134 - val_mae: 4.1118
# Epoch 34/50
# 50/50 [==============================] - 0s 6ms/step - loss: 28.0363 - mae: 3.6009 - val_loss: 30.6770 - val_mae: 4.1693
# Epoch 35/50
# 50/50 [==============================] - 0s 5ms/step - loss: 29.4533 - mae: 3.6489 - val_loss: 30.2470 - val_mae: 4.1264
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 28.6304 - mae: 3.5710 - val_loss: 31.2641 - val_mae: 4.1295
# Epoch 37/50
# 50/50 [==============================] - 0s 6ms/step - loss: 28.9246 - mae: 3.6804 - val_loss: 30.7880 - val_mae: 4.1291
# Epoch 38/50
# 50/50 [==============================] - 0s 5ms/step - loss: 24.4530 - mae: 3.3469 - val_loss: 31.6288 - val_mae: 4.1700
# Epoch 39/50
# 50/50 [==============================] - 0s 6ms/step - loss: 22.7346 - mae: 3.3091 - val_loss: 29.1233 - val_mae: 4.0633
# Epoch 40/50
# 50/50 [==============================] - 0s 7ms/step - loss: 24.5390 - mae: 3.3848 - val_loss: 31.9571 - val_mae: 4.1961
# Epoch 41/50
# 50/50 [==============================] - 0s 6ms/step - loss: 22.5426 - mae: 3.2236 - val_loss: 31.3661 - val_mae: 4.1736
# Epoch 42/50
# 50/50 [==============================] - 0s 6ms/step - loss: 26.0969 - mae: 3.4293 - val_loss: 35.7201 - val_mae: 4.3108
# Epoch 43/50
# 50/50 [==============================] - 0s 6ms/step - loss: 26.7316 - mae: 3.4892 - val_loss: 33.8985 - val_mae: 4.3120
# Epoch 44/50
# 50/50 [==============================] - 0s 5ms/step - loss: 25.3350 - mae: 3.4374 - val_loss: 37.0824 - val_mae: 4.3746
# Epoch 45/50
# 50/50 [==============================] - 0s 6ms/step - loss: 24.6159 - mae: 3.3689 - val_loss: 32.2923 - val_mae: 4.2186
# Epoch 46/50
# 50/50 [==============================] - 0s 6ms/step - loss: 23.7581 - mae: 3.3111 - val_loss: 36.5654 - val_mae: 4.3496
# Epoch 47/50
# 50/50 [==============================] - 0s 6ms/step - loss: 26.8123 - mae: 3.4433 - val_loss: 32.9041 - val_mae: 4.2078
# Epoch 48/50
# 50/50 [==============================] - 0s 6ms/step - loss: 23.6459 - mae: 3.3261 - val_loss: 33.8382 - val_mae: 4.2455
# Epoch 49/50
# 50/50 [==============================] - 0s 6ms/step - loss: 21.1049 - mae: 3.1763 - val_loss: 30.9822 - val_mae: 4.1172
# Epoch 50/50
# 50/50 [==============================] - 0s 5ms/step - loss: 25.8889 - mae: 3.4015 - val_loss: 30.9752 - val_mae: 4.0772
# 13/13 [==============================] - 0s 3ms/step
# Deep Learning Dropout Risk RMSE: 5.57
# Deep Learning Dropout Risk R-squared: 0.94

# %%
# Predict Grade
y_pred_grade = grade_model.predict(X_test_scaled)
y_pred_grade = y_pred_grade.round()  # Round to nearest integer for grades (0-10)

# Predict Dropout Risk (assuming dropout_model is already trained)
y_pred_dropout = dropout_model.predict(X_test_scaled)

# Print predictions for the first few test samples
print("Grade Predictions (first 5):", y_pred_grade[:5])
print("Dropout Risk Predictions (first 5):", y_pred_dropout[:5])
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# Grade Predictions (first 5): [[7.]
#  [7.]
#  [8.]
#  [9.]
#  [7.]]
# Dropout Risk Predictions (first 5): [[20.703045 ]
#  [32.53448  ]
#  [ 9.838882 ]
#  [ 6.1435823]
#  [28.277565 ]]

# %%
import pandas as pd

# Create a DataFrame to compare the actual and predicted values
comparison_df = pd.DataFrame({
    'Actual Grades': y_test_grade,
    'Predicted Grades': y_pred_grade.flatten(),  # Flatten the predictions array
    'Actual Dropout Risk': y_test_dropout,
    'Predicted Dropout Risk': y_pred_dropout.flatten()  # Flatten the predictions array
})

# Display the first 10 rows to compare
print(comparison_df.head(10))
# Out:
#       Actual Grades  Predicted Grades  Actual Dropout Risk  \
# 1860              7               7.0                25.65
# 353               7               7.0                28.20
# 1333              7               8.0                22.47
# 905               9               9.0                 8.16
# 1289              7               7.0                25.02
# 1273              6               6.0                41.55
# 938               6               5.0                49.50
# 1731              8               8.0                11.55
# 65                7               7.0                25.02
# 1323              9               8.0                 4.66
#
#       Predicted Dropout Risk
# 1860               20.703045
# 353                32.534481
# 1333                9.838882
# 905                 6.143582
# 1289               28.277565
# 1273               34.266254
# 938                58.502316
# 1731                8.590672
# 65                 22.335487
# 1323                5.613523

# %%
# Save the grade prediction model
grade_model.save('grade_prediction_model2.h5')

# Save the dropout risk prediction model
dropout_model.save('dropout_risk_prediction_model2.h5')

print("Models saved successfully.")
# Out:
# Models saved successfully.
