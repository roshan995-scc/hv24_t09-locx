# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv('student_data_semester_7.csv')

# Split the data into features and targets
X = df.drop(columns=['Student_ID', 'Grade', 'Dropout_Risk_%'])
y_grade = df['Grade']
y_dropout = df['Dropout_Risk_%']

# Convert Grade to numeric (O = 10, A = 9, B = 8, C = 7, D = 6, E = 5, F = 0)
grade_mapping = {'O': 10,'E': 9 , 'A': 8, 'B': 7, 'C': 6, 'D': 5,  'F': 0}
y_grade = y_grade.map(grade_mapping)

# Split data into train and test sets (80% train, 20% test)
X_train, X_test, y_train_grade, y_test_grade, y_train_dropout, y_test_dropout = train_test_split(
    X, y_grade, y_dropout, test_size=0.2, random_state=42
)

# Standardize the data (important for deep learning models)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
 import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the neural network model
grade_model = Sequential()

# Input layer
grade_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
grade_model.add(Dense(128, activation='relu'))
grade_model.add(Dropout(0.2))
grade_model.add(Dense(64, activation='relu'))
grade_model.add(Dropout(0.2))

# Output layer
grade_model.add(Dense(1, activation='linear'))  # For regression to predict grade numerically

# Compile the model
grade_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Train the model
grade_model.fit(X_train_scaled, y_train_grade, epochs=150, batch_size=32, validation_data=(X_test_scaled, y_test_grade))

# Evaluate the model
y_pred_grade = grade_model.predict(X_test_scaled)
y_pred_grade = y_pred_grade.round()  # Convert continuous output to nearest grade (0-10)

# Calculate accuracy
accuracy = accuracy_score(y_test_grade, y_pred_grade)

print(f"Deep Learning Grade Prediction Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/150
# 50/50 [==============================] - 2s 17ms/step - loss: 17.8821 - accuracy: 0.0025 - val_loss: 3.1938 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 50/50 [==============================] - 0s 6ms/step - loss: 3.5937 - accuracy: 0.0000e+00 - val_loss: 2.4642 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 50/50 [==============================] - 0s 6ms/step - loss: 3.0492 - accuracy: 0.0000e+00 - val_loss: 2.3004 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 50/50 [==============================] - 0s 7ms/step - loss: 2.6865 - accuracy: 0.0000e+00 - val_loss: 1.9966 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.4421 - accuracy: 0.0000e+00 - val_loss: 1.8579 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3507 - accuracy: 0.0000e+00 - val_loss: 1.8689 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 50/50 [==============================] - 0s 4ms/step - loss: 2.1633 - accuracy: 0.0000e+00 - val_loss: 1.6044 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.0164 - accuracy: 0.0000e+00 - val_loss: 1.5151 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.8584 - accuracy: 0.0000e+00 - val_loss: 1.3685 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 50/50 [==============================] - 0s 5ms/step - loss: 1.7084 - accuracy: 0.0000e+00 - val_loss: 1.2786 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.6196 - accuracy: 0.0000e+00 - val_loss: 1.1641 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.5808 - accuracy: 0.0000e+00 - val_loss: 1.0987 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.4596 - accuracy: 0.0000e+00 - val_loss: 1.0948 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.4228 - accuracy: 0.0000e+00 - val_loss: 0.9025 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.3644 - accuracy: 0.0000e+00 - val_loss: 0.8652 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.2886 - accuracy: 0.0000e+00 - val_loss: 0.8476 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.2589 - accuracy: 0.0012 - val_loss: 0.7848 - val_accuracy: 0.0025
# Epoch 18/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.1164 - accuracy: 6.2500e-04 - val_loss: 0.7187 - val_accuracy: 0.0025
# Epoch 19/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.1041 - accuracy: 0.0050 - val_loss: 0.6529 - val_accuracy: 0.0025
# Epoch 20/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.1469 - accuracy: 0.0031 - val_loss: 0.6191 - val_accuracy: 0.0025
# Epoch 21/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.0822 - accuracy: 0.0050 - val_loss: 0.5931 - val_accuracy: 0.0025
# Epoch 22/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.9670 - accuracy: 0.0075 - val_loss: 0.6366 - val_accuracy: 0.0100
# Epoch 23/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.9927 - accuracy: 0.0088 - val_loss: 0.5639 - val_accuracy: 0.0025
# Epoch 24/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.9344 - accuracy: 0.0063 - val_loss: 0.5841 - val_accuracy: 0.0150
# Epoch 25/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.9261 - accuracy: 0.0094 - val_loss: 0.6543 - val_accuracy: 0.0100
# Epoch 26/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.9106 - accuracy: 0.0106 - val_loss: 0.5189 - val_accuracy: 0.0150
# Epoch 27/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8569 - accuracy: 0.0131 - val_loss: 0.5085 - val_accuracy: 0.0125
# Epoch 28/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8482 - accuracy: 0.0125 - val_loss: 0.4881 - val_accuracy: 0.0150
# Epoch 29/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8250 - accuracy: 0.0100 - val_loss: 0.4805 - val_accuracy: 0.0150
# Epoch 30/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8597 - accuracy: 0.0131 - val_loss: 0.4687 - val_accuracy: 0.0125
# Epoch 31/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7666 - accuracy: 0.0131 - val_loss: 0.4432 - val_accuracy: 0.0150
# Epoch 32/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8162 - accuracy: 0.0137 - val_loss: 0.4306 - val_accuracy: 0.0125
# Epoch 33/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7677 - accuracy: 0.0137 - val_loss: 0.4349 - val_accuracy: 0.0150
# Epoch 34/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7268 - accuracy: 0.0150 - val_loss: 0.4775 - val_accuracy: 0.0125
# Epoch 35/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7725 - accuracy: 0.0162 - val_loss: 0.5404 - val_accuracy: 0.0125
# Epoch 36/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7831 - accuracy: 0.0150 - val_loss: 0.3938 - val_accuracy: 0.0125
# Epoch 37/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7585 - accuracy: 0.0137 - val_loss: 0.4037 - val_accuracy: 0.0125
# Epoch 38/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.0150 - val_loss: 0.4004 - val_accuracy: 0.0125
# Epoch 39/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7202 - accuracy: 0.0175 - val_loss: 0.4219 - val_accuracy: 0.0125
# Epoch 40/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7574 - accuracy: 0.0144 - val_loss: 0.4197 - val_accuracy: 0.0125
# Epoch 41/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6613 - accuracy: 0.0162 - val_loss: 0.3939 - val_accuracy: 0.0125
# Epoch 42/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6969 - accuracy: 0.0150 - val_loss: 0.4906 - val_accuracy: 0.0125
# Epoch 43/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7101 - accuracy: 0.0206 - val_loss: 0.4237 - val_accuracy: 0.0150
# Epoch 44/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6672 - accuracy: 0.0150 - val_loss: 0.3941 - val_accuracy: 0.0125
# Epoch 45/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6588 - accuracy: 0.0131 - val_loss: 0.3932 - val_accuracy: 0.0125
# Epoch 46/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.0213 - val_loss: 0.3779 - val_accuracy: 0.0125
# Epoch 47/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.0188 - val_loss: 0.3364 - val_accuracy: 0.0175
# Epoch 48/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6969 - accuracy: 0.0181 - val_loss: 0.3762 - val_accuracy: 0.0125
# Epoch 49/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6529 - accuracy: 0.0200 - val_loss: 0.4098 - val_accuracy: 0.0125
# Epoch 50/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6610 - accuracy: 0.0181 - val_loss: 0.3934 - val_accuracy: 0.0125
# Epoch 51/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.0188 - val_loss: 0.3863 - val_accuracy: 0.0150
# Epoch 52/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6370 - accuracy: 0.0188 - val_loss: 0.3965 - val_accuracy: 0.0125
# Epoch 53/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6561 - accuracy: 0.0181 - val_loss: 0.3709 - val_accuracy: 0.0125
# Epoch 54/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6524 - accuracy: 0.0213 - val_loss: 0.3817 - val_accuracy: 0.0150
# Epoch 55/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6027 - accuracy: 0.0200 - val_loss: 0.3311 - val_accuracy: 0.0150
# Epoch 56/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6323 - accuracy: 0.0181 - val_loss: 0.3276 - val_accuracy: 0.0125
# Epoch 57/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6511 - accuracy: 0.0188 - val_loss: 0.3622 - val_accuracy: 0.0125
# Epoch 58/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6234 - accuracy: 0.0188 - val_loss: 0.3453 - val_accuracy: 0.0150
# Epoch 59/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6032 - accuracy: 0.0206 - val_loss: 0.3695 - val_accuracy: 0.0150
# Epoch 60/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5986 - accuracy: 0.0194 - val_loss: 0.3887 - val_accuracy: 0.0175
# Epoch 61/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6082 - accuracy: 0.0169 - val_loss: 0.3602 - val_accuracy: 0.0125
# Epoch 62/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5715 - accuracy: 0.0206 - val_loss: 0.3723 - val_accuracy: 0.0125
# Epoch 63/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5719 - accuracy: 0.0206 - val_loss: 0.3454 - val_accuracy: 0.0150
# Epoch 64/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5892 - accuracy: 0.0200 - val_loss: 0.3432 - val_accuracy: 0.0125
# Epoch 65/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5764 - accuracy: 0.0213 - val_loss: 0.3686 - val_accuracy: 0.0125
# Epoch 66/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5808 - accuracy: 0.0188 - val_loss: 0.3536 - val_accuracy: 0.0150
# Epoch 67/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5481 - accuracy: 0.0206 - val_loss: 0.3118 - val_accuracy: 0.0175
# Epoch 68/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5715 - accuracy: 0.0206 - val_loss: 0.3388 - val_accuracy: 0.0125
# Epoch 69/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5431 - accuracy: 0.0194 - val_loss: 0.3293 - val_accuracy: 0.0150
# Epoch 70/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5502 - accuracy: 0.0213 - val_loss: 0.3428 - val_accuracy: 0.0125
# Epoch 71/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5859 - accuracy: 0.0206 - val_loss: 0.3465 - val_accuracy: 0.0150
# Epoch 72/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5373 - accuracy: 0.0206 - val_loss: 0.3493 - val_accuracy: 0.0125
# Epoch 73/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5403 - accuracy: 0.0200 - val_loss: 0.3344 - val_accuracy: 0.0150
# Epoch 74/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5182 - accuracy: 0.0200 - val_loss: 0.3219 - val_accuracy: 0.0150
# Epoch 75/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5143 - accuracy: 0.0206 - val_loss: 0.2994 - val_accuracy: 0.0150
# Epoch 76/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.0200 - val_loss: 0.2915 - val_accuracy: 0.0150
# Epoch 77/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5144 - accuracy: 0.0200 - val_loss: 0.3443 - val_accuracy: 0.0125
# Epoch 78/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5357 - accuracy: 0.0219 - val_loss: 0.3340 - val_accuracy: 0.0150
# Epoch 79/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5430 - accuracy: 0.0237 - val_loss: 0.3448 - val_accuracy: 0.0150
# Epoch 80/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.0231 - val_loss: 0.3537 - val_accuracy: 0.0125
# Epoch 81/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4997 - accuracy: 0.0194 - val_loss: 0.3291 - val_accuracy: 0.0150
# Epoch 82/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5084 - accuracy: 0.0213 - val_loss: 0.3234 - val_accuracy: 0.0150
# Epoch 83/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.0237 - val_loss: 0.3318 - val_accuracy: 0.0150
# Epoch 84/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4849 - accuracy: 0.0219 - val_loss: 0.3354 - val_accuracy: 0.0150
# Epoch 85/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.0219 - val_loss: 0.3538 - val_accuracy: 0.0150
# Epoch 86/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4859 - accuracy: 0.0194 - val_loss: 0.3199 - val_accuracy: 0.0200
# Epoch 87/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5134 - accuracy: 0.0225 - val_loss: 0.3680 - val_accuracy: 0.0150
# Epoch 88/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4983 - accuracy: 0.0225 - val_loss: 0.3497 - val_accuracy: 0.0125
# Epoch 89/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4824 - accuracy: 0.0231 - val_loss: 0.3885 - val_accuracy: 0.0125
# Epoch 90/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4705 - accuracy: 0.0250 - val_loss: 0.3505 - val_accuracy: 0.0175
# Epoch 91/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4746 - accuracy: 0.0250 - val_loss: 0.3402 - val_accuracy: 0.0125
# Epoch 92/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4706 - accuracy: 0.0225 - val_loss: 0.3291 - val_accuracy: 0.0125
# Epoch 93/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4191 - accuracy: 0.0225 - val_loss: 0.3278 - val_accuracy: 0.0150
# Epoch 94/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.0256 - val_loss: 0.3280 - val_accuracy: 0.0200
# Epoch 95/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4387 - accuracy: 0.0244 - val_loss: 0.3308 - val_accuracy: 0.0125
# Epoch 96/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4513 - accuracy: 0.0237 - val_loss: 0.3090 - val_accuracy: 0.0150
# Epoch 97/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4594 - accuracy: 0.0225 - val_loss: 0.3725 - val_accuracy: 0.0175
# Epoch 98/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4690 - accuracy: 0.0237 - val_loss: 0.3399 - val_accuracy: 0.0125
# Epoch 99/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4393 - accuracy: 0.0250 - val_loss: 0.4466 - val_accuracy: 0.0150
# Epoch 100/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4814 - accuracy: 0.0231 - val_loss: 0.3402 - val_accuracy: 0.0150
# Epoch 101/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4306 - accuracy: 0.0237 - val_loss: 0.3089 - val_accuracy: 0.0175
# Epoch 102/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.0219 - val_loss: 0.3520 - val_accuracy: 0.0125
# Epoch 103/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.0237 - val_loss: 0.3277 - val_accuracy: 0.0125
# Epoch 104/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3831 - accuracy: 0.0262 - val_loss: 0.3018 - val_accuracy: 0.0125
# Epoch 105/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3945 - accuracy: 0.0250 - val_loss: 0.3062 - val_accuracy: 0.0125
# Epoch 106/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.0237 - val_loss: 0.3052 - val_accuracy: 0.0125
# Epoch 107/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4157 - accuracy: 0.0231 - val_loss: 0.3194 - val_accuracy: 0.0150
# Epoch 108/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3586 - accuracy: 0.0231 - val_loss: 0.3105 - val_accuracy: 0.0175
# Epoch 109/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4251 - accuracy: 0.0256 - val_loss: 0.3363 - val_accuracy: 0.0150
# Epoch 110/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.0262 - val_loss: 0.3169 - val_accuracy: 0.0150
# Epoch 111/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3902 - accuracy: 0.0237 - val_loss: 0.3240 - val_accuracy: 0.0150
# Epoch 112/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4235 - accuracy: 0.0237 - val_loss: 0.3191 - val_accuracy: 0.0150
# Epoch 113/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3889 - accuracy: 0.0256 - val_loss: 0.3539 - val_accuracy: 0.0150
# Epoch 114/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3990 - accuracy: 0.0269 - val_loss: 0.3490 - val_accuracy: 0.0150
# Epoch 115/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4241 - accuracy: 0.0231 - val_loss: 0.3564 - val_accuracy: 0.0175
# Epoch 116/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3980 - accuracy: 0.0225 - val_loss: 0.3929 - val_accuracy: 0.0150
# Epoch 117/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4091 - accuracy: 0.0237 - val_loss: 0.3164 - val_accuracy: 0.0175
# Epoch 118/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3905 - accuracy: 0.0225 - val_loss: 0.3343 - val_accuracy: 0.0125
# Epoch 119/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3715 - accuracy: 0.0244 - val_loss: 0.3426 - val_accuracy: 0.0125
# Epoch 120/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4057 - accuracy: 0.0237 - val_loss: 0.3728 - val_accuracy: 0.0150
# Epoch 121/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3671 - accuracy: 0.0250 - val_loss: 0.3047 - val_accuracy: 0.0225
# Epoch 122/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3623 - accuracy: 0.0231 - val_loss: 0.3569 - val_accuracy: 0.0150
# Epoch 123/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3947 - accuracy: 0.0256 - val_loss: 0.3541 - val_accuracy: 0.0150
# Epoch 124/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3558 - accuracy: 0.0250 - val_loss: 0.3457 - val_accuracy: 0.0175
# Epoch 125/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3728 - accuracy: 0.0231 - val_loss: 0.3721 - val_accuracy: 0.0150
# Epoch 126/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4007 - accuracy: 0.0262 - val_loss: 0.3216 - val_accuracy: 0.0225
# Epoch 127/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3660 - accuracy: 0.0225 - val_loss: 0.3252 - val_accuracy: 0.0150
# Epoch 128/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.0225 - val_loss: 0.3215 - val_accuracy: 0.0225
# Epoch 129/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3681 - accuracy: 0.0250 - val_loss: 0.3248 - val_accuracy: 0.0150
# Epoch 130/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3614 - accuracy: 0.0262 - val_loss: 0.3297 - val_accuracy: 0.0225
# Epoch 131/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3952 - accuracy: 0.0256 - val_loss: 0.3565 - val_accuracy: 0.0175
# Epoch 132/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4008 - accuracy: 0.0256 - val_loss: 0.3214 - val_accuracy: 0.0225
# Epoch 133/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3641 - accuracy: 0.0250 - val_loss: 0.3281 - val_accuracy: 0.0200
# Epoch 134/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3564 - accuracy: 0.0244 - val_loss: 0.3096 - val_accuracy: 0.0225
# Epoch 135/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.0250 - val_loss: 0.3037 - val_accuracy: 0.0225
# Epoch 136/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3906 - accuracy: 0.0256 - val_loss: 0.3297 - val_accuracy: 0.0200
# Epoch 137/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3874 - accuracy: 0.0244 - val_loss: 0.3210 - val_accuracy: 0.0225
# Epoch 138/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3625 - accuracy: 0.0225 - val_loss: 0.3280 - val_accuracy: 0.0200
# Epoch 139/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3416 - accuracy: 0.0244 - val_loss: 0.3724 - val_accuracy: 0.0200
# Epoch 140/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3357 - accuracy: 0.0231 - val_loss: 0.3611 - val_accuracy: 0.0150
# Epoch 141/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3373 - accuracy: 0.0250 - val_loss: 0.3110 - val_accuracy: 0.0175
# Epoch 142/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3433 - accuracy: 0.0237 - val_loss: 0.3434 - val_accuracy: 0.0175
# Epoch 143/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.0250 - val_loss: 0.3762 - val_accuracy: 0.0125
# Epoch 144/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3460 - accuracy: 0.0244 - val_loss: 0.3492 - val_accuracy: 0.0200
# Epoch 145/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3733 - accuracy: 0.0250 - val_loss: 0.4078 - val_accuracy: 0.0200
# Epoch 146/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3726 - accuracy: 0.0231 - val_loss: 0.3518 - val_accuracy: 0.0225
# Epoch 147/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3793 - accuracy: 0.0250 - val_loss: 0.3362 - val_accuracy: 0.0225
# Epoch 148/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3704 - accuracy: 0.0219 - val_loss: 0.3638 - val_accuracy: 0.0225
# Epoch 149/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3382 - accuracy: 0.0256 - val_loss: 0.3633 - val_accuracy: 0.0200
# Epoch 150/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3451 - accuracy: 0.0250 - val_loss: 0.3816 - val_accuracy: 0.0150
# 13/13 [==============================] - 0s 2ms/step
# Deep Learning Grade Prediction Accuracy: 75.00%

# %%
# Build the neural network model for dropout risk prediction
dropout_model = Sequential()

# Input layer
dropout_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
dropout_model.add(Dense(128, activation='relu'))
dropout_model.add(Dropout(0.2))
dropout_model.add(Dense(64, activation='relu'))
dropout_model.add(Dropout(0.2))

# Output layer
dropout_model.add(Dense(1, activation='linear'))  # For regression to predict dropout risk

# Compile the model
dropout_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
dropout_model.fit(X_train_scaled, y_train_dropout, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test_dropout))

# Evaluate the model
y_pred_dropout = dropout_model.predict(X_test_scaled)

from sklearn.metrics import mean_squared_error, r2_score

# Calculate RMSE (Root Mean Squared Error)
dropout_rmse = mean_squared_error(y_test_dropout, y_pred_dropout) ** 0.5

# Calculate R-squared score
dropout_r2 = r2_score(y_test_dropout, y_pred_dropout)

print(f"Deep Learning Dropout Risk RMSE: {dropout_rmse:.2f}")
print(f"Deep Learning Dropout Risk R-squared: {dropout_r2:.2f}")
# Out:
# Epoch 1/50
# 50/50 [==============================] - 2s 19ms/step - loss: 900.9473 - mae: 21.3288 - val_loss: 257.8548 - val_mae: 12.2472
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 130.4243 - mae: 8.4715 - val_loss: 56.1234 - val_mae: 5.4181
# Epoch 3/50
# 50/50 [==============================] - 0s 6ms/step - loss: 68.4126 - mae: 5.8426 - val_loss: 50.7210 - val_mae: 5.1602
# Epoch 4/50
# 50/50 [==============================] - 0s 6ms/step - loss: 56.2890 - mae: 5.4580 - val_loss: 47.8986 - val_mae: 5.1009
# Epoch 5/50
# 50/50 [==============================] - 0s 6ms/step - loss: 54.8394 - mae: 5.3766 - val_loss: 45.5118 - val_mae: 4.9824
# Epoch 6/50
# 50/50 [==============================] - 0s 7ms/step - loss: 57.3497 - mae: 5.4860 - val_loss: 44.9304 - val_mae: 4.9643
# Epoch 7/50
# 50/50 [==============================] - 0s 6ms/step - loss: 56.6895 - mae: 5.4134 - val_loss: 57.1705 - val_mae: 5.3200
# Epoch 8/50
# 50/50 [==============================] - 0s 6ms/step - loss: 55.0317 - mae: 5.3154 - val_loss: 44.9977 - val_mae: 5.0073
# Epoch 9/50
# 50/50 [==============================] - 0s 6ms/step - loss: 51.4665 - mae: 5.1450 - val_loss: 48.1774 - val_mae: 5.1184
# Epoch 10/50
# 50/50 [==============================] - 0s 5ms/step - loss: 50.8198 - mae: 5.0621 - val_loss: 44.7105 - val_mae: 4.9627
# Epoch 11/50
# 50/50 [==============================] - 0s 6ms/step - loss: 50.3506 - mae: 5.1405 - val_loss: 42.1248 - val_mae: 4.7947
# Epoch 12/50
# 50/50 [==============================] - 0s 6ms/step - loss: 51.5055 - mae: 5.1039 - val_loss: 42.0829 - val_mae: 4.7786
# Epoch 13/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.5749 - mae: 4.9615 - val_loss: 44.0001 - val_mae: 4.8949
# Epoch 14/50
# 50/50 [==============================] - 0s 6ms/step - loss: 48.2431 - mae: 4.9016 - val_loss: 42.3480 - val_mae: 4.7355
# Epoch 15/50
# 50/50 [==============================] - 0s 6ms/step - loss: 49.2681 - mae: 4.9836 - val_loss: 42.0530 - val_mae: 4.7297
# Epoch 16/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.5826 - mae: 4.8063 - val_loss: 40.6143 - val_mae: 4.6307
# Epoch 17/50
# 50/50 [==============================] - 0s 5ms/step - loss: 47.4214 - mae: 4.7967 - val_loss: 40.3629 - val_mae: 4.6529
# Epoch 18/50
# 50/50 [==============================] - 0s 5ms/step - loss: 39.6264 - mae: 4.4751 - val_loss: 46.6101 - val_mae: 4.9780
# Epoch 19/50
# 50/50 [==============================] - 0s 6ms/step - loss: 43.3088 - mae: 4.5105 - val_loss: 53.2764 - val_mae: 5.1928
# Epoch 20/50
# 50/50 [==============================] - 0s 6ms/step - loss: 42.8251 - mae: 4.6220 - val_loss: 39.1253 - val_mae: 4.5794
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 39.9118 - mae: 4.4469 - val_loss: 40.5208 - val_mae: 4.5316
# Epoch 22/50
# 50/50 [==============================] - 0s 6ms/step - loss: 39.2021 - mae: 4.4038 - val_loss: 41.8674 - val_mae: 4.7944
# Epoch 23/50
# 50/50 [==============================] - 0s 5ms/step - loss: 42.5805 - mae: 4.5304 - val_loss: 43.2745 - val_mae: 4.7488
# Epoch 24/50
# 50/50 [==============================] - 0s 6ms/step - loss: 41.9179 - mae: 4.5110 - val_loss: 40.5955 - val_mae: 4.6071
# Epoch 25/50
# 50/50 [==============================] - 0s 6ms/step - loss: 39.0732 - mae: 4.3201 - val_loss: 42.0632 - val_mae: 4.6965
# Epoch 26/50
# 50/50 [==============================] - 0s 6ms/step - loss: 37.7345 - mae: 4.2930 - val_loss: 38.7190 - val_mae: 4.5050
# Epoch 27/50
# 50/50 [==============================] - 0s 7ms/step - loss: 39.6090 - mae: 4.3080 - val_loss: 42.6416 - val_mae: 4.6881
# Epoch 28/50
# 50/50 [==============================] - 0s 6ms/step - loss: 38.3425 - mae: 4.2532 - val_loss: 40.9500 - val_mae: 4.5695
# Epoch 29/50
# 50/50 [==============================] - 0s 6ms/step - loss: 38.7402 - mae: 4.2356 - val_loss: 41.3872 - val_mae: 4.6080
# Epoch 30/50
# 50/50 [==============================] - 0s 6ms/step - loss: 37.3790 - mae: 4.2591 - val_loss: 40.1549 - val_mae: 4.4621
# Epoch 31/50
# 50/50 [==============================] - 0s 7ms/step - loss: 36.9025 - mae: 4.2285 - val_loss: 41.8999 - val_mae: 4.6502
# Epoch 32/50
# 50/50 [==============================] - 0s 5ms/step - loss: 36.1107 - mae: 4.1765 - val_loss: 43.6933 - val_mae: 4.5962
# Epoch 33/50
# 50/50 [==============================] - 0s 7ms/step - loss: 37.4166 - mae: 4.1682 - val_loss: 41.9228 - val_mae: 4.5855
# Epoch 34/50
# 50/50 [==============================] - 0s 6ms/step - loss: 36.7042 - mae: 4.1551 - val_loss: 42.0273 - val_mae: 4.5394
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 33.2626 - mae: 4.0026 - val_loss: 45.9929 - val_mae: 4.7813
# Epoch 36/50
# 50/50 [==============================] - 0s 6ms/step - loss: 35.2904 - mae: 4.1103 - val_loss: 41.3069 - val_mae: 4.5821
# Epoch 37/50
# 50/50 [==============================] - 0s 6ms/step - loss: 38.8756 - mae: 4.1776 - val_loss: 41.6190 - val_mae: 4.5524
# Epoch 38/50
# 50/50 [==============================] - 0s 6ms/step - loss: 33.9760 - mae: 4.0459 - val_loss: 41.9374 - val_mae: 4.5282
# Epoch 39/50
# 50/50 [==============================] - 0s 5ms/step - loss: 34.7269 - mae: 4.0253 - val_loss: 43.9443 - val_mae: 4.5749
# Epoch 40/50
# 50/50 [==============================] - 0s 5ms/step - loss: 33.2178 - mae: 3.9992 - val_loss: 42.4575 - val_mae: 4.6392
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 32.5530 - mae: 3.8760 - val_loss: 49.6446 - val_mae: 4.7349
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 34.2352 - mae: 3.9598 - val_loss: 41.7896 - val_mae: 4.5888
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 36.0310 - mae: 4.0248 - val_loss: 42.1854 - val_mae: 4.6519
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 34.4877 - mae: 4.0384 - val_loss: 46.4542 - val_mae: 4.9052
# Epoch 45/50
# 50/50 [==============================] - 0s 6ms/step - loss: 32.7114 - mae: 3.9947 - val_loss: 43.6537 - val_mae: 4.6862
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 32.9361 - mae: 3.8599 - val_loss: 46.5083 - val_mae: 4.8410
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 33.1951 - mae: 3.9648 - val_loss: 42.2133 - val_mae: 4.6195
# Epoch 48/50
# 50/50 [==============================] - 0s 7ms/step - loss: 31.5028 - mae: 3.7766 - val_loss: 42.3635 - val_mae: 4.5814
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 33.8830 - mae: 3.8537 - val_loss: 44.0739 - val_mae: 4.5462
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 34.0605 - mae: 3.9635 - val_loss: 44.1361 - val_mae: 4.6885
# 13/13 [==============================] - 0s 7ms/step
# Deep Learning Dropout Risk RMSE: 6.64
# Deep Learning Dropout Risk R-squared: 0.92

# %%
import pandas as pd

# Create a DataFrame to compare the actual and predicted values
comparison_df = pd.DataFrame({
    'Actual Grades': y_test_grade,
    'Predicted Grades': y_pred_grade.flatten(),  # Flatten the predictions array
    'Actual Dropout Risk': y_test_dropout,
    'Predicted Dropout Risk': y_pred_dropout.flatten()  # Flatten the predictions array
})

# Display the first 10 rows to compare
print(comparison_df.head(10))
# Out:
#       Actual Grades  Predicted Grades  Actual Dropout Risk  \
# 1860             10              11.0                 0.00
# 353               9               9.0                10.41
# 1333              7               7.0                27.10
# 905               7               7.0                31.10
# 1289              8               8.0                14.64
# 1273              7               7.0                28.19
# 938               8               8.0                13.55
# 1731              7               7.0                26.02
# 65                8               9.0                 9.92
# 1323              8               7.0                16.82
#
#       Predicted Dropout Risk
# 1860                0.040450
# 353                12.058973
# 1333               31.609241
# 905                47.254482
# 1289               17.111547
# 1273               26.262516
# 938                11.531208
# 1731               34.728748
# 65                  5.050732
# 1323               20.181952

# %%
# Save the grade prediction model
grade_model.save('grade_prediction_model7.h5')

# Save the dropout risk prediction model
dropout_model.save('dropout_risk_prediction_model7.h5')

print("Models saved successfully.")
# Out:
# Models saved successfully.
