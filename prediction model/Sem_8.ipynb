# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv('student_data_semester_8.csv')

# Split the data into features and targets
X = df.drop(columns=['Student_ID', 'Grade', 'Dropout_Risk_%'])
y_grade = df['Grade']
y_dropout = df['Dropout_Risk_%']

# Convert Grade to numeric (O = 10, A = 9, B = 8, C = 7, D = 6, E = 5, F = 0)
grade_mapping = {'O': 10,'E': 9 , 'A': 8, 'B': 7, 'C': 6, 'D': 5,  'F': 0}
y_grade = y_grade.map(grade_mapping)

# Split data into train and test sets (80% train, 20% test)
X_train, X_test, y_train_grade, y_test_grade, y_train_dropout, y_test_dropout = train_test_split(
    X, y_grade, y_dropout, test_size=0.2, random_state=42
)

# Standardize the data (important for deep learning models)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
 import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the neural network model
grade_model = Sequential()

# Input layer
grade_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
grade_model.add(Dense(128, activation='relu'))
grade_model.add(Dropout(0.2))
grade_model.add(Dense(64, activation='relu'))
grade_model.add(Dropout(0.2))

# Output layer
grade_model.add(Dense(1, activation='linear'))  # For regression to predict grade numerically

# Compile the model
grade_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Train the model
grade_model.fit(X_train_scaled, y_train_grade, epochs=150, batch_size=32, validation_data=(X_test_scaled, y_test_grade))

# Evaluate the model
y_pred_grade = grade_model.predict(X_test_scaled)
y_pred_grade = y_pred_grade.round()  # Convert continuous output to nearest grade (0-10)

# Calculate accuracy
accuracy = accuracy_score(y_test_grade, y_pred_grade)

print(f"Deep Learning Grade Prediction Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/150
# 50/50 [==============================] - 1s 11ms/step - loss: 13.8119 - accuracy: 0.0012 - val_loss: 3.2518 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 50/50 [==============================] - 0s 5ms/step - loss: 3.5061 - accuracy: 0.0000e+00 - val_loss: 2.4317 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0559 - accuracy: 0.0000e+00 - val_loss: 2.0632 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 50/50 [==============================] - 0s 5ms/step - loss: 2.5809 - accuracy: 0.0000e+00 - val_loss: 1.8167 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3271 - accuracy: 0.0000e+00 - val_loss: 1.7662 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 50/50 [==============================] - 0s 4ms/step - loss: 2.1350 - accuracy: 0.0000e+00 - val_loss: 1.5220 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 50/50 [==============================] - 0s 4ms/step - loss: 1.8847 - accuracy: 0.0000e+00 - val_loss: 1.4534 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 50/50 [==============================] - 0s 4ms/step - loss: 1.8154 - accuracy: 0.0000e+00 - val_loss: 1.3037 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 50/50 [==============================] - 0s 4ms/step - loss: 1.6522 - accuracy: 0.0000e+00 - val_loss: 1.2283 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.5391 - accuracy: 0.0000e+00 - val_loss: 1.1703 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.4374 - accuracy: 0.0000e+00 - val_loss: 1.0705 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.3055 - accuracy: 0.0000e+00 - val_loss: 0.9976 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.3079 - accuracy: 6.2500e-04 - val_loss: 0.9168 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.1830 - accuracy: 6.2500e-04 - val_loss: 0.8265 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.1994 - accuracy: 6.2500e-04 - val_loss: 0.7809 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 50/50 [==============================] - 0s 7ms/step - loss: 1.1775 - accuracy: 0.0000e+00 - val_loss: 0.7387 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.0592 - accuracy: 0.0019 - val_loss: 0.6885 - val_accuracy: 0.0025
# Epoch 18/150
# 50/50 [==============================] - 0s 6ms/step - loss: 1.0136 - accuracy: 0.0012 - val_loss: 0.6352 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.9428 - accuracy: 0.0044 - val_loss: 0.6431 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8970 - accuracy: 0.0037 - val_loss: 0.5980 - val_accuracy: 0.0025
# Epoch 21/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.9171 - accuracy: 0.0031 - val_loss: 0.5243 - val_accuracy: 0.0025
# Epoch 22/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8452 - accuracy: 0.0050 - val_loss: 0.5235 - val_accuracy: 0.0025
# Epoch 23/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.9014 - accuracy: 0.0050 - val_loss: 0.5905 - val_accuracy: 0.0025
# Epoch 24/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8441 - accuracy: 0.0088 - val_loss: 0.5460 - val_accuracy: 0.0025
# Epoch 25/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7789 - accuracy: 0.0081 - val_loss: 0.4405 - val_accuracy: 0.0025
# Epoch 26/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7706 - accuracy: 0.0081 - val_loss: 0.4769 - val_accuracy: 0.0075
# Epoch 27/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7689 - accuracy: 0.0081 - val_loss: 0.4545 - val_accuracy: 0.0075
# Epoch 28/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7835 - accuracy: 0.0113 - val_loss: 0.5069 - val_accuracy: 0.0075
# Epoch 29/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7818 - accuracy: 0.0137 - val_loss: 0.4455 - val_accuracy: 0.0075
# Epoch 30/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7153 - accuracy: 0.0119 - val_loss: 0.4229 - val_accuracy: 0.0075
# Epoch 31/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7814 - accuracy: 0.0113 - val_loss: 0.4897 - val_accuracy: 0.0075
# Epoch 32/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7083 - accuracy: 0.0106 - val_loss: 0.4195 - val_accuracy: 0.0075
# Epoch 33/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7398 - accuracy: 0.0125 - val_loss: 0.4114 - val_accuracy: 0.0075
# Epoch 34/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7394 - accuracy: 0.0113 - val_loss: 0.3795 - val_accuracy: 0.0125
# Epoch 35/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7537 - accuracy: 0.0100 - val_loss: 0.4470 - val_accuracy: 0.0050
# Epoch 36/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7071 - accuracy: 0.0106 - val_loss: 0.3990 - val_accuracy: 0.0125
# Epoch 37/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6642 - accuracy: 0.0181 - val_loss: 0.4228 - val_accuracy: 0.0075
# Epoch 38/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6527 - accuracy: 0.0144 - val_loss: 0.4026 - val_accuracy: 0.0075
# Epoch 39/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6702 - accuracy: 0.0169 - val_loss: 0.3662 - val_accuracy: 0.0075
# Epoch 40/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6199 - accuracy: 0.0144 - val_loss: 0.3801 - val_accuracy: 0.0125
# Epoch 41/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6229 - accuracy: 0.0113 - val_loss: 0.3880 - val_accuracy: 0.0100
# Epoch 42/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6262 - accuracy: 0.0119 - val_loss: 0.3803 - val_accuracy: 0.0100
# Epoch 43/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6449 - accuracy: 0.0119 - val_loss: 0.3552 - val_accuracy: 0.0075
# Epoch 44/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6891 - accuracy: 0.0150 - val_loss: 0.5334 - val_accuracy: 0.0050
# Epoch 45/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6828 - accuracy: 0.0131 - val_loss: 0.4379 - val_accuracy: 0.0100
# Epoch 46/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.0144 - val_loss: 0.3727 - val_accuracy: 0.0050
# Epoch 47/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6227 - accuracy: 0.0169 - val_loss: 0.3650 - val_accuracy: 0.0100
# Epoch 48/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6277 - accuracy: 0.0156 - val_loss: 0.3275 - val_accuracy: 0.0075
# Epoch 49/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6477 - accuracy: 0.0156 - val_loss: 0.3608 - val_accuracy: 0.0150
# Epoch 50/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6009 - accuracy: 0.0144 - val_loss: 0.3783 - val_accuracy: 0.0075
# Epoch 51/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6058 - accuracy: 0.0169 - val_loss: 0.3930 - val_accuracy: 0.0075
# Epoch 52/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5719 - accuracy: 0.0144 - val_loss: 0.3805 - val_accuracy: 0.0100
# Epoch 53/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5938 - accuracy: 0.0181 - val_loss: 0.3808 - val_accuracy: 0.0100
# Epoch 54/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6470 - accuracy: 0.0144 - val_loss: 0.3675 - val_accuracy: 0.0075
# Epoch 55/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6274 - accuracy: 0.0137 - val_loss: 0.4200 - val_accuracy: 0.0150
# Epoch 56/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5691 - accuracy: 0.0175 - val_loss: 0.3481 - val_accuracy: 0.0150
# Epoch 57/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5682 - accuracy: 0.0188 - val_loss: 0.3797 - val_accuracy: 0.0100
# Epoch 58/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5598 - accuracy: 0.0169 - val_loss: 0.3841 - val_accuracy: 0.0150
# Epoch 59/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5717 - accuracy: 0.0181 - val_loss: 0.3513 - val_accuracy: 0.0150
# Epoch 60/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5573 - accuracy: 0.0175 - val_loss: 0.3462 - val_accuracy: 0.0150
# Epoch 61/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 0.0169 - val_loss: 0.3746 - val_accuracy: 0.0150
# Epoch 62/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5561 - accuracy: 0.0181 - val_loss: 0.3537 - val_accuracy: 0.0150
# Epoch 63/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5624 - accuracy: 0.0175 - val_loss: 0.3589 - val_accuracy: 0.0100
# Epoch 64/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5375 - accuracy: 0.0200 - val_loss: 0.3202 - val_accuracy: 0.0150
# Epoch 65/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5328 - accuracy: 0.0194 - val_loss: 0.3673 - val_accuracy: 0.0125
# Epoch 66/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5538 - accuracy: 0.0194 - val_loss: 0.3476 - val_accuracy: 0.0150
# Epoch 67/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.0181 - val_loss: 0.3536 - val_accuracy: 0.0150
# Epoch 68/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5389 - accuracy: 0.0175 - val_loss: 0.3464 - val_accuracy: 0.0150
# Epoch 69/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5317 - accuracy: 0.0194 - val_loss: 0.3510 - val_accuracy: 0.0150
# Epoch 70/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.0169 - val_loss: 0.3403 - val_accuracy: 0.0150
# Epoch 71/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.0188 - val_loss: 0.4302 - val_accuracy: 0.0150
# Epoch 72/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4917 - accuracy: 0.0194 - val_loss: 0.3459 - val_accuracy: 0.0125
# Epoch 73/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5303 - accuracy: 0.0181 - val_loss: 0.3346 - val_accuracy: 0.0150
# Epoch 74/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5144 - accuracy: 0.0194 - val_loss: 0.3792 - val_accuracy: 0.0150
# Epoch 75/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.0219 - val_loss: 0.3270 - val_accuracy: 0.0125
# Epoch 76/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5328 - accuracy: 0.0194 - val_loss: 0.3218 - val_accuracy: 0.0150
# Epoch 77/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4892 - accuracy: 0.0206 - val_loss: 0.3407 - val_accuracy: 0.0150
# Epoch 78/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.0213 - val_loss: 0.3517 - val_accuracy: 0.0150
# Epoch 79/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5241 - accuracy: 0.0181 - val_loss: 0.3726 - val_accuracy: 0.0150
# Epoch 80/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4855 - accuracy: 0.0169 - val_loss: 0.3450 - val_accuracy: 0.0150
# Epoch 81/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4504 - accuracy: 0.0162 - val_loss: 0.3589 - val_accuracy: 0.0100
# Epoch 82/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4627 - accuracy: 0.0213 - val_loss: 0.3318 - val_accuracy: 0.0150
# Epoch 83/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4687 - accuracy: 0.0194 - val_loss: 0.3689 - val_accuracy: 0.0125
# Epoch 84/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4708 - accuracy: 0.0200 - val_loss: 0.3908 - val_accuracy: 0.0100
# Epoch 85/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4747 - accuracy: 0.0194 - val_loss: 0.3379 - val_accuracy: 0.0150
# Epoch 86/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4728 - accuracy: 0.0194 - val_loss: 0.3385 - val_accuracy: 0.0150
# Epoch 87/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4879 - accuracy: 0.0200 - val_loss: 0.3168 - val_accuracy: 0.0150
# Epoch 88/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4649 - accuracy: 0.0200 - val_loss: 0.3322 - val_accuracy: 0.0150
# Epoch 89/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4513 - accuracy: 0.0194 - val_loss: 0.3675 - val_accuracy: 0.0150
# Epoch 90/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4371 - accuracy: 0.0200 - val_loss: 0.3726 - val_accuracy: 0.0125
# Epoch 91/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4371 - accuracy: 0.0225 - val_loss: 0.3882 - val_accuracy: 0.0150
# Epoch 92/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4592 - accuracy: 0.0200 - val_loss: 0.3386 - val_accuracy: 0.0150
# Epoch 93/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4653 - accuracy: 0.0188 - val_loss: 0.3622 - val_accuracy: 0.0150
# Epoch 94/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4660 - accuracy: 0.0194 - val_loss: 0.3576 - val_accuracy: 0.0150
# Epoch 95/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4455 - accuracy: 0.0225 - val_loss: 0.3568 - val_accuracy: 0.0150
# Epoch 96/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4278 - accuracy: 0.0213 - val_loss: 0.3642 - val_accuracy: 0.0150
# Epoch 97/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4441 - accuracy: 0.0181 - val_loss: 0.3737 - val_accuracy: 0.0100
# Epoch 98/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4324 - accuracy: 0.0213 - val_loss: 0.3487 - val_accuracy: 0.0150
# Epoch 99/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4119 - accuracy: 0.0194 - val_loss: 0.3627 - val_accuracy: 0.0150
# Epoch 100/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4373 - accuracy: 0.0213 - val_loss: 0.3696 - val_accuracy: 0.0100
# Epoch 101/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4559 - accuracy: 0.0213 - val_loss: 0.3810 - val_accuracy: 0.0150
# Epoch 102/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4283 - accuracy: 0.0219 - val_loss: 0.3282 - val_accuracy: 0.0150
# Epoch 103/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4494 - accuracy: 0.0206 - val_loss: 0.3437 - val_accuracy: 0.0150
# Epoch 104/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4140 - accuracy: 0.0219 - val_loss: 0.3650 - val_accuracy: 0.0150
# Epoch 105/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4511 - accuracy: 0.0194 - val_loss: 0.4113 - val_accuracy: 0.0150
# Epoch 106/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4202 - accuracy: 0.0194 - val_loss: 0.3852 - val_accuracy: 0.0150
# Epoch 107/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4449 - accuracy: 0.0213 - val_loss: 0.3716 - val_accuracy: 0.0150
# Epoch 108/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4056 - accuracy: 0.0200 - val_loss: 0.3585 - val_accuracy: 0.0125
# Epoch 109/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4599 - accuracy: 0.0225 - val_loss: 0.4153 - val_accuracy: 0.0150
# Epoch 110/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4167 - accuracy: 0.0200 - val_loss: 0.4229 - val_accuracy: 0.0150
# Epoch 111/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4186 - accuracy: 0.0219 - val_loss: 0.3894 - val_accuracy: 0.0150
# Epoch 112/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3948 - accuracy: 0.0194 - val_loss: 0.3674 - val_accuracy: 0.0150
# Epoch 113/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4390 - accuracy: 0.0231 - val_loss: 0.3824 - val_accuracy: 0.0150
# Epoch 114/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4293 - accuracy: 0.0213 - val_loss: 0.3797 - val_accuracy: 0.0100
# Epoch 115/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4218 - accuracy: 0.0200 - val_loss: 0.4014 - val_accuracy: 0.0150
# Epoch 116/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3963 - accuracy: 0.0225 - val_loss: 0.3452 - val_accuracy: 0.0150
# Epoch 117/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.0231 - val_loss: 0.4109 - val_accuracy: 0.0125
# Epoch 118/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4124 - accuracy: 0.0200 - val_loss: 0.3630 - val_accuracy: 0.0125
# Epoch 119/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.0219 - val_loss: 0.3939 - val_accuracy: 0.0150
# Epoch 120/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4028 - accuracy: 0.0194 - val_loss: 0.3620 - val_accuracy: 0.0125
# Epoch 121/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3578 - accuracy: 0.0213 - val_loss: 0.3718 - val_accuracy: 0.0150
# Epoch 122/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.0194 - val_loss: 0.3613 - val_accuracy: 0.0150
# Epoch 123/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4120 - accuracy: 0.0219 - val_loss: 0.4117 - val_accuracy: 0.0150
# Epoch 124/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3901 - accuracy: 0.0219 - val_loss: 0.3915 - val_accuracy: 0.0125
# Epoch 125/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3685 - accuracy: 0.0213 - val_loss: 0.3908 - val_accuracy: 0.0125
# Epoch 126/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3933 - accuracy: 0.0231 - val_loss: 0.3719 - val_accuracy: 0.0100
# Epoch 127/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3804 - accuracy: 0.0194 - val_loss: 0.3480 - val_accuracy: 0.0150
# Epoch 128/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3711 - accuracy: 0.0206 - val_loss: 0.3626 - val_accuracy: 0.0125
# Epoch 129/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3739 - accuracy: 0.0213 - val_loss: 0.3832 - val_accuracy: 0.0150
# Epoch 130/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3840 - accuracy: 0.0225 - val_loss: 0.3594 - val_accuracy: 0.0125
# Epoch 131/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3843 - accuracy: 0.0219 - val_loss: 0.3426 - val_accuracy: 0.0150
# Epoch 132/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3530 - accuracy: 0.0244 - val_loss: 0.3662 - val_accuracy: 0.0150
# Epoch 133/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.0200 - val_loss: 0.3526 - val_accuracy: 0.0150
# Epoch 134/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3759 - accuracy: 0.0206 - val_loss: 0.3638 - val_accuracy: 0.0150
# Epoch 135/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3417 - accuracy: 0.0225 - val_loss: 0.3579 - val_accuracy: 0.0150
# Epoch 136/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.0206 - val_loss: 0.3516 - val_accuracy: 0.0125
# Epoch 137/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3756 - accuracy: 0.0219 - val_loss: 0.3572 - val_accuracy: 0.0125
# Epoch 138/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3545 - accuracy: 0.0219 - val_loss: 0.3456 - val_accuracy: 0.0125
# Epoch 139/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3362 - accuracy: 0.0194 - val_loss: 0.3471 - val_accuracy: 0.0150
# Epoch 140/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3826 - accuracy: 0.0219 - val_loss: 0.3497 - val_accuracy: 0.0150
# Epoch 141/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3889 - accuracy: 0.0194 - val_loss: 0.3613 - val_accuracy: 0.0150
# Epoch 142/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3580 - accuracy: 0.0225 - val_loss: 0.3857 - val_accuracy: 0.0125
# Epoch 143/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3629 - accuracy: 0.0194 - val_loss: 0.3487 - val_accuracy: 0.0125
# Epoch 144/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.0181 - val_loss: 0.3967 - val_accuracy: 0.0125
# Epoch 145/150
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3482 - accuracy: 0.0206 - val_loss: 0.3533 - val_accuracy: 0.0150
# Epoch 146/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3514 - accuracy: 0.0213 - val_loss: 0.3911 - val_accuracy: 0.0125
# Epoch 147/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3342 - accuracy: 0.0250 - val_loss: 0.3812 - val_accuracy: 0.0125
# Epoch 148/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3186 - accuracy: 0.0219 - val_loss: 0.3994 - val_accuracy: 0.0125
# Epoch 149/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3414 - accuracy: 0.0231 - val_loss: 0.3691 - val_accuracy: 0.0150
# Epoch 150/150
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3301 - accuracy: 0.0225 - val_loss: 0.3986 - val_accuracy: 0.0125
# 13/13 [==============================] - 0s 3ms/step
# Deep Learning Grade Prediction Accuracy: 80.00%

# %%
# Build the neural network model for dropout risk prediction
dropout_model = Sequential()

# Input layer
dropout_model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))

# Hidden layers
dropout_model.add(Dense(128, activation='relu'))
dropout_model.add(Dropout(0.2))
dropout_model.add(Dense(64, activation='relu'))
dropout_model.add(Dropout(0.2))

# Output layer
dropout_model.add(Dense(1, activation='linear'))  # For regression to predict dropout risk

# Compile the model
dropout_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
dropout_model.fit(X_train_scaled, y_train_dropout, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test_dropout))

# Evaluate the model
y_pred_dropout = dropout_model.predict(X_test_scaled)

from sklearn.metrics import mean_squared_error, r2_score

# Calculate RMSE (Root Mean Squared Error)
dropout_rmse = mean_squared_error(y_test_dropout, y_pred_dropout) ** 0.5

# Calculate R-squared score
dropout_r2 = r2_score(y_test_dropout, y_pred_dropout)

print(f"Deep Learning Dropout Risk RMSE: {dropout_rmse:.2f}")
print(f"Deep Learning Dropout Risk R-squared: {dropout_r2:.2f}")
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 10ms/step - loss: 764.2533 - mae: 19.6340 - val_loss: 190.5124 - val_mae: 11.8531
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 95.9968 - mae: 7.3591 - val_loss: 46.1572 - val_mae: 4.9465
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 58.8572 - mae: 5.5845 - val_loss: 43.0982 - val_mae: 4.8548
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 61.5358 - mae: 5.6438 - val_loss: 43.4098 - val_mae: 4.8300
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 55.9733 - mae: 5.3413 - val_loss: 40.9437 - val_mae: 4.7411
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 53.3669 - mae: 5.1824 - val_loss: 42.8749 - val_mae: 4.7399
# Epoch 7/50
# 50/50 [==============================] - 0s 5ms/step - loss: 54.4852 - mae: 5.3918 - val_loss: 40.4013 - val_mae: 4.6468
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 52.0032 - mae: 5.1530 - val_loss: 38.8450 - val_mae: 4.5738
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 50.9870 - mae: 5.1466 - val_loss: 39.5092 - val_mae: 4.6330
# Epoch 10/50
# 50/50 [==============================] - 0s 7ms/step - loss: 52.9121 - mae: 5.0486 - val_loss: 39.7448 - val_mae: 4.5925
# Epoch 11/50
# 50/50 [==============================] - 0s 5ms/step - loss: 50.0250 - mae: 4.9801 - val_loss: 42.4581 - val_mae: 4.6809
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 50.7512 - mae: 5.0955 - val_loss: 39.0582 - val_mae: 4.5442
# Epoch 13/50
# 50/50 [==============================] - 0s 6ms/step - loss: 54.7332 - mae: 5.1963 - val_loss: 37.3931 - val_mae: 4.4156
# Epoch 14/50
# 50/50 [==============================] - 0s 6ms/step - loss: 44.6552 - mae: 4.6982 - val_loss: 39.6103 - val_mae: 4.4740
# Epoch 15/50
# 50/50 [==============================] - 0s 6ms/step - loss: 44.9967 - mae: 4.7246 - val_loss: 36.5168 - val_mae: 4.3700
# Epoch 16/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.2628 - mae: 4.7930 - val_loss: 36.0126 - val_mae: 4.3334
# Epoch 17/50
# 50/50 [==============================] - 0s 7ms/step - loss: 46.1141 - mae: 4.6342 - val_loss: 36.4599 - val_mae: 4.3257
# Epoch 18/50
# 50/50 [==============================] - 0s 6ms/step - loss: 46.6528 - mae: 4.8052 - val_loss: 37.3907 - val_mae: 4.3515
# Epoch 19/50
# 50/50 [==============================] - 0s 6ms/step - loss: 42.8699 - mae: 4.5520 - val_loss: 38.5289 - val_mae: 4.3991
# Epoch 20/50
# 50/50 [==============================] - 0s 5ms/step - loss: 41.4219 - mae: 4.4907 - val_loss: 36.2272 - val_mae: 4.2983
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 41.9720 - mae: 4.4765 - val_loss: 37.7856 - val_mae: 4.3333
# Epoch 22/50
# 50/50 [==============================] - 0s 6ms/step - loss: 39.9163 - mae: 4.3876 - val_loss: 40.6796 - val_mae: 4.4560
# Epoch 23/50
# 50/50 [==============================] - 0s 6ms/step - loss: 42.5034 - mae: 4.4969 - val_loss: 42.8329 - val_mae: 4.5470
# Epoch 24/50
# 50/50 [==============================] - 0s 6ms/step - loss: 42.2894 - mae: 4.5520 - val_loss: 36.9336 - val_mae: 4.3093
# Epoch 25/50
# 50/50 [==============================] - 0s 7ms/step - loss: 40.0842 - mae: 4.3765 - val_loss: 40.1111 - val_mae: 4.4434
# Epoch 26/50
# 50/50 [==============================] - 0s 5ms/step - loss: 36.9284 - mae: 4.3088 - val_loss: 42.0851 - val_mae: 4.4694
# Epoch 27/50
# 50/50 [==============================] - 0s 6ms/step - loss: 41.5556 - mae: 4.4378 - val_loss: 35.3360 - val_mae: 4.1768
# Epoch 28/50
# 50/50 [==============================] - 0s 6ms/step - loss: 38.3098 - mae: 4.2538 - val_loss: 36.7670 - val_mae: 4.2338
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 39.9493 - mae: 4.2628 - val_loss: 38.4612 - val_mae: 4.3046
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 41.3376 - mae: 4.3740 - val_loss: 37.1547 - val_mae: 4.2691
# Epoch 31/50
# 50/50 [==============================] - 0s 7ms/step - loss: 37.5583 - mae: 4.1550 - val_loss: 37.9010 - val_mae: 4.2157
# Epoch 32/50
# 50/50 [==============================] - 0s 6ms/step - loss: 38.1349 - mae: 4.1343 - val_loss: 45.3404 - val_mae: 4.6160
# Epoch 33/50
# 50/50 [==============================] - 0s 5ms/step - loss: 37.4267 - mae: 4.1303 - val_loss: 35.1409 - val_mae: 4.1380
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 34.8470 - mae: 4.0821 - val_loss: 35.4436 - val_mae: 4.1710
# Epoch 35/50
# 50/50 [==============================] - 0s 7ms/step - loss: 36.8683 - mae: 4.1425 - val_loss: 35.0297 - val_mae: 4.1353
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 40.2358 - mae: 4.2431 - val_loss: 42.0397 - val_mae: 4.4380
# Epoch 37/50
# 50/50 [==============================] - 0s 5ms/step - loss: 39.3572 - mae: 4.2687 - val_loss: 34.5941 - val_mae: 4.0556
# Epoch 38/50
# 50/50 [==============================] - 0s 7ms/step - loss: 34.4558 - mae: 4.0595 - val_loss: 35.4552 - val_mae: 4.1547
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 32.0011 - mae: 3.9506 - val_loss: 35.5544 - val_mae: 4.1742
# Epoch 40/50
# 50/50 [==============================] - 0s 5ms/step - loss: 36.5108 - mae: 4.0860 - val_loss: 38.2189 - val_mae: 4.2553
# Epoch 41/50
# 50/50 [==============================] - 0s 5ms/step - loss: 35.1852 - mae: 4.0832 - val_loss: 37.3727 - val_mae: 4.1609
# Epoch 42/50
# 50/50 [==============================] - 0s 5ms/step - loss: 33.8189 - mae: 3.9347 - val_loss: 37.1193 - val_mae: 4.1617
# Epoch 43/50
# 50/50 [==============================] - 0s 6ms/step - loss: 34.5898 - mae: 3.9754 - val_loss: 36.3656 - val_mae: 4.2127
# Epoch 44/50
# 50/50 [==============================] - 0s 5ms/step - loss: 34.7769 - mae: 3.9454 - val_loss: 35.3517 - val_mae: 4.1165
# Epoch 45/50
# 50/50 [==============================] - 0s 6ms/step - loss: 36.6534 - mae: 4.0119 - val_loss: 36.2679 - val_mae: 4.1802
# Epoch 46/50
# 50/50 [==============================] - 0s 6ms/step - loss: 33.3604 - mae: 3.9323 - val_loss: 35.9633 - val_mae: 4.0993
# Epoch 47/50
# 50/50 [==============================] - 0s 7ms/step - loss: 37.4865 - mae: 4.1522 - val_loss: 36.9971 - val_mae: 4.1885
# Epoch 48/50
# 50/50 [==============================] - 0s 6ms/step - loss: 30.9610 - mae: 3.8540 - val_loss: 41.3803 - val_mae: 4.4278
# Epoch 49/50
# 50/50 [==============================] - 0s 7ms/step - loss: 32.0549 - mae: 3.8629 - val_loss: 36.4930 - val_mae: 4.2109
# Epoch 50/50
# 50/50 [==============================] - 0s 5ms/step - loss: 35.8646 - mae: 3.9195 - val_loss: 38.2297 - val_mae: 4.1923
# 13/13 [==============================] - 0s 3ms/step
# Deep Learning Dropout Risk RMSE: 6.18
# Deep Learning Dropout Risk R-squared: 0.93

# %%
import pandas as pd

# Create a DataFrame to compare the actual and predicted values
comparison_df = pd.DataFrame({
    'Actual Grades': y_test_grade,
    'Predicted Grades': y_pred_grade.flatten(),  # Flatten the predictions array
    'Actual Dropout Risk': y_test_dropout,
    'Predicted Dropout Risk': y_pred_dropout.flatten()  # Flatten the predictions array
})

# Display the first 10 rows to compare
print(comparison_df.head(10))
# Out:
#       Actual Grades  Predicted Grades  Actual Dropout Risk  \
# 1860              7               7.0                30.38
# 353               7               6.0                32.61
# 1333              6               6.0                52.33
# 905               7               7.0                29.64
# 1289              5               5.0                77.75
# 1273              7               7.0                27.40
# 938               8               8.0                10.54
# 1731              8               7.0                13.14
# 65                9               8.0                 5.08
# 1323              9               9.0                 2.48
#
#       Predicted Dropout Risk
# 1860               34.357132
# 353                41.786854
# 1333               57.983185
# 905                19.533859
# 1289               84.892090
# 1273               27.616964
# 938                11.962786
# 1731               21.479883
# 65                  6.355339
# 1323                4.616837

# %%
# Save the grade prediction model
grade_model.save('grade_prediction_model8.h5')

# Save the dropout risk prediction model
dropout_model.save('dropout_risk_prediction_model8.h5')

print("Models saved successfully.")
# Out:
# Models saved successfully.
